# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ('./Data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
mask = df['total_rooms'] < 3

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 1

# %%
## Remove unseen samples

data = df.sample(frac=0.95,random_state=28)
data_unseen = df.drop(data.index)

print(f'Data for model: {data.shape},\nData for unseen predictions: { data_unseen.shape}')
# Out:
# Data for model: (19608, 10),
# Data for unseen predictions: (1032, 10)

# %%
##from pycaret.regression import *
## reg = setup(data = data, target='median_house_value', normalize=True, session_id=42)

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        201
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data['total_bedrooms'].count()
# Out:
# 19407

# %%
data.shape
# Out:
# (19608, 10)

# %%
from pycaret.regression import *
reg = setup(data = data, target='median_house_value', normalize=True)
reg
# Out:
# <style type="text/css">
# #T_44029_row10_col1, #T_44029_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_44029">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44029_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_44029_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44029_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_44029_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_44029_row0_col1" class="data row0 col1" >4898</td>
#     </tr>
#     <tr>
#       <th id="T_44029_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_44029_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_44029_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
# ...

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        201
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
## checking for nulls

# %%
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        201
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
data['total_bedrooms'].describe()
# Out:
# count    19407.000000
# mean       538.259597
# std        419.823427
# min          1.000000
# 25%        297.000000
# 50%        436.000000
# 75%        648.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5179     -118.26     33.95                44.0       1771.0           378.0
# 11988    -117.51     34.00                36.0       3791.0           746.0
# 9522     -123.21     39.14                15.0       2235.0           545.0
# 18792    -122.57     40.61                27.0       1540.0           315.0
# 17209    -119.72     34.43                33.0       1028.0           377.0
#
#        population  households  median_income  median_house_value  \
# 5179       1296.0       399.0         1.6389             96700.0
# 11988      2258.0       672.0         3.2067            124700.0
# 9522       1376.0       516.0         1.9032            100000.0
# 18792       883.0       321.0         2.8036             93400.0
# 17209       753.0       356.0         2.3454            243800.0
#
#       ocean_proximity
# 5179        <1H OCEAN
# 11988          INLAND
# 9522        <1H OCEAN
# 18792          INLAND
# ...

# %%
data['total_bedrooms']
# Out:
# 5179     378.0
# 11988    746.0
# 9522     545.0
# 18792    315.0
# 17209    377.0
#          ...
# 19888    414.0
# 15727    194.0
# 2270     456.0
# 6826     525.0
# 14317    180.0
# Name: total_bedrooms, Length: 19608, dtype: float64

# %%
data['total_bedrooms'].describe()
# Out:
# count    19407.000000
# mean       538.259597
# std        419.823427
# min          1.000000
# 25%        297.000000
# 50%        436.000000
# 75%        648.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
data['total_bedrooms'] = data['total_bedrooms'].fillna(538)

# %%
data.isnull().sum()   ## No Nulls
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
data.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5179     -118.26     33.95                44.0       1771.0           378.0
# 11988    -117.51     34.00                36.0       3791.0           746.0
# 9522     -123.21     39.14                15.0       2235.0           545.0
# 18792    -122.57     40.61                27.0       1540.0           315.0
# 17209    -119.72     34.43                33.0       1028.0           377.0
#
#        population  households  median_income  median_house_value  \
# 5179       1296.0       399.0         1.6389             96700.0
# 11988      2258.0       672.0         3.2067            124700.0
# 9522       1376.0       516.0         1.9032            100000.0
# 18792       883.0       321.0         2.8036             93400.0
# 17209       753.0       356.0         2.3454            243800.0
#
#       ocean_proximity
# 5179        <1H OCEAN
# 11988          INLAND
# 9522        <1H OCEAN
# 18792          INLAND
# ...

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
## data.to_csv('./Data/cl_data.csv', index=False)

# %%
data['total_rooms'] < data ['total_bedrooms']
# Out:
# 5179     False
# 11988    False
# 9522     False
# 18792    False
# 17209    False
#          ...
# 19888    False
# 15727    False
# 2270     False
# 6826     False
# 14317    False
# Length: 19608, dtype: bool

# %%
## Comparing Models

# %%
compare_models(include = ['catboost','rf','lightgbm'])
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:28:47
# Status     . . . . . . . . . . . . . . . . . .   Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor

# %%
pull()
# Out:
#                                     Model         MAE           MSE  \
# catboost               CatBoost Regressor  30515.2589  2.100042e+09
# lightgbm  Light Gradient Boosting Machine  32171.7782  2.288374e+09
# rf                Random Forest Regressor  32277.6946  2.426279e+09
#
#                 RMSE      R2   RMSLE    MAPE  TT (Sec)
# catboost  45792.3116  0.8415  0.2282  0.1711     6.398
# lightgbm  47797.9077  0.8273  0.2362  0.1802     2.230
# rf        49210.6668  0.8169  0.2377  0.1797     6.036

# %%
##compare_models()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32540\4280754256.py in <cell line: 1>()
# ----> 1 compare_models()
#
# NameError: name 'compare_models' is not defined

# %%
## working with two of the top models

# %%
catboost = create_model('catboost')
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            11:33:10
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
lightgbm = create_model('lightgbm')
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:33:37
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_9eab2_row10_col0, #T_9eab2_row10_col1, #T_9eab2_row10_col2, #T_9eab2_row10_col3, #T_9eab2_row10_col4, #T_9eab2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9eab2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eab2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9eab2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9eab2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9eab2_level0_col3" class="col_heading level0 col3" >R2</th>
# ...

# %%
## default is 10 folds but we can make it 15 folds... for improved fitting

# %%
## Tunning with 10 folds

# %%
lightgbm_tuned_model = tune_model(lightgbm)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
pull()
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# Fold
# 0     33302.4939  2.341166e+09  48385.6005  0.8306  0.2468  0.1881
# 1     33180.5576  2.483326e+09  49832.9819  0.8093  0.2434  0.1839
# 2     32673.7376  2.223647e+09  47155.5648  0.8299  0.2366  0.1725
# 3     33457.3855  2.564421e+09  50640.1141  0.8090  0.2696  0.2046
# 4     32899.8756  2.254766e+09  47484.3724  0.8224  0.2360  0.1783
# 5     33072.2063  2.243605e+09  47366.7095  0.8286  0.2454  0.1842
# 6     31025.5489  1.990021e+09  44609.6464  0.8439  0.2358  0.1811
# 7     34153.6745  2.302515e+09  47984.5329  0.8315  0.2570  0.1960
# 8     32653.6088  2.295460e+09  47910.9642  0.8221  0.2558  0.1859
# 9     34258.8386  2.595687e+09  50947.8855  0.8151  0.2570  0.1904
# Mean  33067.7927  2.329462e+09  48231.8372  0.8242  0.2483  0.1865
# Std     856.9198  1.706292e+08   1775.2160  0.0104  0.0107  0.0086

# %%
## Tunning with 15 folds

# %%
lightgbm_tuned_model2 = tune_model(lightgbm ,  fold = 15)
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         11:39:52
# Status                Loading Dependencies
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_85b84_row15_col0, #T_85b84_row15_col1, #T_85b84_row15_col2, #T_85b84_row15_col3, #T_85b84_row15_col4, #T_85b84_row15_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_85b84">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85b84_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_85b84_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_85b84_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_85b84_level0_col3" class="col_heading level0 col3" >R2</th>
# ...

# %%
tune_model(lightgbm ,  fold = 15)
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         18:11:44
# Status           Searching Hyperparameters
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_01048_row15_col0, #T_01048_row15_col1, #T_01048_row15_col2, #T_01048_row15_col3, #T_01048_row15_col4, #T_01048_row15_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_01048">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01048_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_01048_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_01048_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_01048_level0_col3" class="col_heading level0 col3" >R2</th>
# ...

# %%
## FINALIZING AND SAVING MODEL

# %%
print(lightgbm)
# Out:
# LGBMRegressor(random_state=4898)

# %%
##print(lightgbm_tuned_model)
# Out:
# LGBMRegressor(random_state=1807)

# %%
final_model = finalize_model(lightgbm)
final_model
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['longitude', 'latitude',
#                                              'housing_median_age',
#                                              'total_rooms', 'total_bedrooms',
#                                              'population', 'households',
#                                              'median_income'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['ocean_proximity'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['ocean_proximity'],
#                                     transformer=OneHotEncoder(cols=['ocean_proximity'],
# ...

# %%
save_model(final_model, './models/housing_lightgbm')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['longitude', 'latitude',
#                                               'housing_median_age',
#                                               'total_rooms', 'total_bedrooms',
#                                               'population', 'households',
#                                               'median_income'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['ocean_proximity'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['ocean_proximity'],
# ...

# %%
## Load model and test on unseen data.

# %%
model_test = load_model('./models/housing_lightgbm')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
## Try change the titles and state if its in sqft or measurements

# %%
data_test = [[ -117.51,	34.00,	36.0,	3791.0,	746.0,	2258.0,	672.0,	3.2067,'INLAND']]

# %%
data_test
# Out:
# [[-117.51, 34.0, 36.0, 3791.0, 746.0, 2258.0, 672.0, 3.2067, 'INLAND']]

# %%
data_test
pd.DataFrame(data_test)
# Out:
#         0     1     2       3      4       5      6       7       8
# 0 -117.51  34.0  36.0  3791.0  746.0  2258.0  672.0  3.2067  INLAND

# %%
#or  ##df[:1:]

# %%
cols = model_test.feature_names_in_[:-1]
cols
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity']

# %%
pd.DataFrame(cols)
# Out:
#                     0
# 0           longitude
# 1            latitude
# 2  housing_median_age
# 3         total_rooms
# 4      total_bedrooms
# 5          population
# 6          households
# 7       median_income
# 8     ocean_proximity

# %%
pd.DataFrame(cols)
# Out:
#                     0
# 0           longitude
# 1            latitude
# 2  housing_median_age
# 3         total_rooms
# 4      total_bedrooms
# 5          population
# 6          households
# 7       median_income
# 8     ocean_proximity

# %%
cols = model_test.feature_names_in_[:-1]
test_data = pd.DataFrame(data_test, columns=cols)
prediction = model_test.predict(test_data)[0]
prediction
# Out:
# 123314.5654849839

# %%
act_pred = 124700.0
act_pred
# Out:
# 124700.0

# %%
cols = model_test.feature_names_in_[:-1]
test_data = pd.DataFrame(data_test, columns=cols)
prediction = model_test.predict(test_data)[0]
prediction
# Out:
# 123314.5654849839

# %%
new_pred = prediction.round(2)
new_pred
# Out:
# 123314.57

# %%
MAE = act_pred - new_pred
MAE
# Out:
# 1385.429999999993

# %%
MPAE = MAE/act_pred
MPAE
# Out:
# 0.011110104250200425

# %%
### EDA starts on unseend data

# %%
data_unseen
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 57       -122.28     37.82                52.0       1489.0           335.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# 111      -122.25     37.82                32.0       3809.0          1098.0
# 159      -122.24     37.81                52.0       2093.0           550.0
# ...          ...       ...                 ...          ...             ...
# 20572    -121.98     38.52                27.0       3044.0           565.0
# 20596    -121.57     39.16                33.0       2033.0           375.0
# 20601    -121.57     39.13                30.0        442.0           103.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20620    -121.48     39.05                40.0        198.0            41.0
#
# ...

# %%
unseen_batch = data_unseen.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity']]
unseen_batch
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 57       -122.28     37.82                52.0       1489.0           335.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# 111      -122.25     37.82                32.0       3809.0          1098.0
# 159      -122.24     37.81                52.0       2093.0           550.0
# ...          ...       ...                 ...          ...             ...
# 20572    -121.98     38.52                27.0       3044.0           565.0
# 20596    -121.57     39.16                33.0       2033.0           375.0
# 20601    -121.57     39.13                30.0        442.0           103.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20620    -121.48     39.05                40.0        198.0            41.0
#
# ...

# %%
unseen_batch.shape
# Out:
# (1032, 9)

# %%
data_unseen.shape
# Out:
# (1032, 10)

# %%
## Predicton on the Batch of unseen data

# %%
unseen_predictions = model_test.predict(unseen_batch)
unseen_predictions
# Out:
# array([337499.79965556, 127948.59622107, 180406.20164688, ...,
#         70142.68269389,  83697.94919706, 151521.28281654])

# %%
data_unseen['y-hat'] = np.round(unseen_predictions,2)
data_unseen['y-hat']
# Out:
# 3        337499.80
# 57       127948.60
# 60       180406.20
# 111      203132.83
# 159      197554.07
#            ...
# 20572    104720.50
# 20596    105867.17
# 20601     70142.68
# 20612     83697.95
# 20620    151521.28
# Name: y-hat, Length: 1032, dtype: float64

# %%
data_unseen['pct_err'] = (abs(data_unseen['median_house_value'] - data_unseen['y-hat'])) / data_unseen['median_house_value']
data_unseen
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 57       -122.28     37.82                52.0       1489.0           335.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# 111      -122.25     37.82                32.0       3809.0          1098.0
# 159      -122.24     37.81                52.0       2093.0           550.0
# ...          ...       ...                 ...          ...             ...
# 20572    -121.98     38.52                27.0       3044.0           565.0
# 20596    -121.57     39.16                33.0       2033.0           375.0
# 20601    -121.57     39.13                30.0        442.0           103.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20620    -121.48     39.05                40.0        198.0            41.0
#
# ...

# %%
data_unseen
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 57       -122.28     37.82                52.0       1489.0           335.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# 111      -122.25     37.82                32.0       3809.0          1098.0
# 159      -122.24     37.81                52.0       2093.0           550.0
# ...          ...       ...                 ...          ...             ...
# 20572    -121.98     38.52                27.0       3044.0           565.0
# 20596    -121.57     39.16                33.0       2033.0           375.0
# 20601    -121.57     39.13                30.0        442.0           103.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20620    -121.48     39.05                40.0        198.0            41.0
#
# ...

# %%
data_unseen = data_unseen.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity','median_house_value']]

# %%
data_unseen['y-hat'] = np.round(unseen_predictions,2)
data_unseen['y-hat']
# Out:
# 3        337499.80
# 57       127948.60
# 60       180406.20
# 111      203132.83
# 159      197554.07
#            ...
# 20572    104720.50
# 20596    105867.17
# 20601     70142.68
# 20612     83697.95
# 20620    151521.28
# Name: y-hat, Length: 1032, dtype: float64

# %%
data_unseen['pct_err'] = (abs(data_unseen['median_house_value'] - data_unseen['y-hat'])) / data_unseen['median_house_value']
data_unseen
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 3        -122.25     37.85                52.0       1274.0           235.0
# 57       -122.28     37.82                52.0       1489.0           335.0
# 60       -122.29     37.83                52.0       1121.0           211.0
# 111      -122.25     37.82                32.0       3809.0          1098.0
# 159      -122.24     37.81                52.0       2093.0           550.0
# ...          ...       ...                 ...          ...             ...
# 20572    -121.98     38.52                27.0       3044.0           565.0
# 20596    -121.57     39.16                33.0       2033.0           375.0
# 20601    -121.57     39.13                30.0        442.0           103.0
# 20612    -121.56     39.08                26.0       1377.0           289.0
# 20620    -121.48     39.05                40.0        198.0            41.0
#
# ...

# %%
## checking the unseen_ourliars

# %%
outliars_unseen = data_unseen[data_unseen['pct_err'] > 0.15].shape
outliars_unseen
# Out:
# (438, 12)

# %%
data_unseen.shape
# Out:
# (1032, 12)

# %%
MAE = outliars_unseen[0]/ data_unseen.shape[0]
MAE
# Out:
# 0.42441860465116277
