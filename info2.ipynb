# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('./Data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = df[['housing_median_age','total_rooms','total_bedrooms','population', 'households', 'median_income','median_house_value', 'ocean_proximity']]


df_sub
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20635                25.0       1665.0           374.0       845.0
# 20636                18.0        697.0           150.0       356.0
# 20637                17.0       2254.0           485.0      1007.0
# 20638                18.0       1860.0           409.0       741.0
# 20639                16.0       2785.0           616.0      1387.0
#
#        households  median_income  median_house_value ocean_proximity
# 0           126.0         8.3252            452600.0        NEAR BAY
# ...

# %%
df_sub = df.rename(columns={'housing_median_age': 'housing_median_age',
                         'total_rooms': 'total_rooms_sqft', 
                         'total_bedrooms': 'total_bedrooms_sqft',
                          'population': 'population', 
                          'median_income': 'median_income',
                          'median_house_value': 'median_house_value',
                           'ocean_proximity': 'ocean_proximity'})

df_sub
# Out:
#        housing_median_age  total_rooms_sqft  total_bedrooms_sqft  population  \
# 0                    41.0             880.0                129.0       322.0
# 1                    21.0            7099.0               1106.0      2401.0
# 2                    52.0            1467.0                190.0       496.0
# 3                    52.0            1274.0                235.0       558.0
# 4                    52.0            1627.0                280.0       565.0
# ...                   ...               ...                  ...         ...
# 20635                25.0            1665.0                374.0       845.0
# 20636                18.0             697.0                150.0       356.0
# 20637                17.0            2254.0                485.0      1007.0
# 20638                18.0            1860.0                409.0       741.0
# 20639                16.0            2785.0                616.0      1387.0
#
# ...

# %%
df.isnull().count()
# Out:
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20640
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
df.shape
# Out:
# (20640, 8)

# %%
df.isnull().sum()
# Out:
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(537)
# Out:
# C:\Users\juud0\AppData\Local\Temp\ipykernel_37340\4143570459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_bedrooms'] = df['total_bedrooms'].fillna(537)

# %%
df.isnull().sum()
# Out:
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   housing_median_age  20640 non-null  float64
#  1   total_rooms         20640 non-null  float64
#  2   total_bedrooms      20640 non-null  float64
#  3   population          20640 non-null  float64
#  4   households          20640 non-null  float64
#  5   median_income       20640 non-null  float64
#  6   median_house_value  20640 non-null  float64
#  7   ocean_proximity     20640 non-null  object
# dtypes: float64(7), object(1)
# memory usage: 1.3+ MB

# %%
df.hist(figsize = (15, 8))
# Out:
# array([[<AxesSubplot: title={'center': 'housing_median_age'}>,
#         <AxesSubplot: title={'center': 'total_rooms'}>,
#         <AxesSubplot: title={'center': 'total_bedrooms'}>],
#        [<AxesSubplot: title={'center': 'population'}>,
#         <AxesSubplot: title={'center': 'households'}>,
#         <AxesSubplot: title={'center': 'median_income'}>],
#        [<AxesSubplot: title={'center': 'median_house_value'}>,
#         <AxesSubplot: >, <AxesSubplot: >]], dtype=object)

# %%
#df['total_rooms'] = np.log(df['total_rooms'] + 1)
#df['total_bedrooms'] = np.log(df['total_bedrooms'] + 1)
#df['population'] = np.log(df['population'] + 1)
#df['households'] = np.log(df['households'] + 1)

# %%
#train[(train['price'] < 2100000) & (train['price'] > 300000)]

# %%
df['total_rooms'].describe()
# Out:
# count    20640.000000
# mean         7.629377
# std          0.749991
# min          1.098612
# 25%          7.278456
# 50%          7.662938
# 75%          8.054840
# max         10.579514
# Name: total_rooms, dtype: float64

# %%
df.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                41.0     6.781058        4.867534    5.777652    4.844187
# 1                21.0     8.867850        7.009409    7.784057    7.037906
# 2                52.0     7.291656        5.252273    6.208590    5.181784
# 3                52.0     7.150701        5.463832    6.326149    5.393628
# 4                52.0     7.395108        5.638355    6.338594    5.560682
#
#    median_income  median_house_value ocean_proximity
# 0         8.3252            452600.0        NEAR BAY
# 1         8.3014            358500.0        NEAR BAY
# 2         7.2574            352100.0        NEAR BAY
# 3         5.6431            341300.0        NEAR BAY
# 4         3.8462            342200.0        NEAR BAY

# %%
df['total_rooms'].plot(kind='box', vert=True)
# Out:
# <AxesSubplot: >

# %%
df['index'] = range(1, len(df)+1)   ##creating an index to plot
# Out:
# C:\Users\juud0\AppData\Local\Temp\ipykernel_37340\55339619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['index'] = range(1, len(df)+1)   ##creating an index to plot

# %%
df.head()
# Out:
#    housing_median_age  total_rooms  total_bedrooms  population  households  \
# 0                41.0     6.781058        4.867534    5.777652    4.844187
# 1                21.0     8.867850        7.009409    7.784057    7.037906
# 2                52.0     7.291656        5.252273    6.208590    5.181784
# 3                52.0     7.150701        5.463832    6.326149    5.393628
# 4                52.0     7.395108        5.638355    6.338594    5.560682
#
#    median_income  median_house_value ocean_proximity  index
# 0         8.3252            452600.0        NEAR BAY      1
# 1         8.3014            358500.0        NEAR BAY      2
# 2         7.2574            352100.0        NEAR BAY      3
# 3         5.6431            341300.0        NEAR BAY      4
# 4         3.8462            342200.0        NEAR BAY      5

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
sns.lmplot(data=df, x ='index', y='total_rooms')

# %%
mask = df['total_rooms'] < 3

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 14

# %%
mask = df['total_rooms'] < 3

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 14

# %%
mask = df['total_rooms'] < 4

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 65

# %%
## clean total number of rooms

# %%
df[(df['total_rooms'] > 4) & (df['total_rooms']  < 10)].count()
# Out:
# housing_median_age    20556
# total_rooms           20556
# total_bedrooms        20556
# population            20556
# households            20556
# median_income         20556
# median_house_value    20556
# ocean_proximity       20556
# index                 20556
# dtype: int64

# %%
cln_trooms = df[(df['total_rooms'] > 4) & (df['total_rooms']  < 10)]
cln_trooms
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0     6.781058        4.867534    5.777652
# 1                    21.0     8.867850        7.009409    7.784057
# 2                    52.0     7.291656        5.252273    6.208590
# 3                    52.0     7.150701        5.463832    6.326149
# 4                    52.0     7.395108        5.638355    6.338594
# ...                   ...          ...             ...         ...
# 20635                25.0     7.418181        5.926926    6.740519
# 20636                18.0     6.548219        5.017280    5.877736
# 20637                17.0     7.720905        6.186209    6.915723
# 20638                18.0     7.528869        6.016157    6.609349
# 20639                16.0     7.932362        6.424869    7.235619
#
#        households  median_income  median_house_value ocean_proximity  index
# 0        4.844187         8.3252            452600.0        NEAR BAY      1
# ...

# %%
cln_trooms.count()
# Out:
# housing_median_age    20556
# total_rooms           20556
# total_bedrooms        20556
# population            20556
# households            20556
# median_income         20556
# median_house_value    20556
# ocean_proximity       20556
# index                 20556
# dtype: int64

# %%
df.shape
# Out:
# (20640, 9)

# %%
df = cln_trooms

# %%
df.shape
# Out:
# (20556, 9)

# %%
### cleaning total_bedrooms,   next :population , households , median_income

# %%
sns.lmplot(data=df, x ='index', y='total_bedrooms')

# %%
mask = df['total_bedrooms'] < 3.5

mask2 = df['total_bedrooms'][mask]
mask2.count()
# Out:
# 120

# %%
cln_bedrooms = df[(df['total_bedrooms'] > 3.5) & (df['total_bedrooms']  < 8)]
cln_bedrooms
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0     6.781058        4.867534    5.777652
# 1                    21.0     8.867850        7.009409    7.784057
# 2                    52.0     7.291656        5.252273    6.208590
# 3                    52.0     7.150701        5.463832    6.326149
# 4                    52.0     7.395108        5.638355    6.338594
# ...                   ...          ...             ...         ...
# 20635                25.0     7.418181        5.926926    6.740519
# 20636                18.0     6.548219        5.017280    5.877736
# 20637                17.0     7.720905        6.186209    6.915723
# 20638                18.0     7.528869        6.016157    6.609349
# 20639                16.0     7.932362        6.424869    7.235619
#
#        households  median_income  median_house_value ocean_proximity  index
# 0        4.844187         8.3252            452600.0        NEAR BAY      1
# ...

# %%
df = cln_bedrooms

# %%
df.shape
# Out:
# (20385, 9)

# %%
## cleaning the population , households , median_income

# %%
sns.lmplot(data=df, x ='index', y='population')

# %%
cln_population = df[(df['population'] > 5) & (df['population']  < 9)]
cln_population
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0     6.781058        4.867534    5.777652
# 1                    21.0     8.867850        7.009409    7.784057
# 2                    52.0     7.291656        5.252273    6.208590
# 3                    52.0     7.150701        5.463832    6.326149
# 4                    52.0     7.395108        5.638355    6.338594
# ...                   ...          ...             ...         ...
# 20635                25.0     7.418181        5.926926    6.740519
# 20636                18.0     6.548219        5.017280    5.877736
# 20637                17.0     7.720905        6.186209    6.915723
# 20638                18.0     7.528869        6.016157    6.609349
# 20639                16.0     7.932362        6.424869    7.235619
#
#        households  median_income  median_house_value ocean_proximity  index
# 0        4.844187         8.3252            452600.0        NEAR BAY      1
# ...

# %%
df = cln_population

# %%
df.shape
# Out:
# (20185, 9)

# %%
## Cleanig Houshold

# %%
sns.lmplot(data=df, x ='index', y='households')

# %%
cln_households = df[(df['households'] > 4) & (df['households']  < 8)]
cln_households
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0     6.781058        4.867534    5.777652
# 1                    21.0     8.867850        7.009409    7.784057
# 2                    52.0     7.291656        5.252273    6.208590
# 3                    52.0     7.150701        5.463832    6.326149
# 4                    52.0     7.395108        5.638355    6.338594
# ...                   ...          ...             ...         ...
# 20635                25.0     7.418181        5.926926    6.740519
# 20636                18.0     6.548219        5.017280    5.877736
# 20637                17.0     7.720905        6.186209    6.915723
# 20638                18.0     7.528869        6.016157    6.609349
# 20639                16.0     7.932362        6.424869    7.235619
#
#        households  median_income  median_house_value ocean_proximity  index
# 0        4.844187         8.3252            452600.0        NEAR BAY      1
# ...

# %%
df = cln_households

# %%
df.shape
# Out:
# (20147, 9)

# %%
## cleaning the  median_income

# %%
sns.lmplot(data=df, x ='index', y='median_income')

# %%
cln_mincome = df[(df['median_income'] > 0.5) & (df['median_income']  < 10)]
cln_mincome
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0     6.781058        4.867534    5.777652
# 1                    21.0     8.867850        7.009409    7.784057
# 2                    52.0     7.291656        5.252273    6.208590
# 3                    52.0     7.150701        5.463832    6.326149
# 4                    52.0     7.395108        5.638355    6.338594
# ...                   ...          ...             ...         ...
# 20635                25.0     7.418181        5.926926    6.740519
# 20636                18.0     6.548219        5.017280    5.877736
# 20637                17.0     7.720905        6.186209    6.915723
# 20638                18.0     7.528869        6.016157    6.609349
# 20639                16.0     7.932362        6.424869    7.235619
#
#        households  median_income  median_house_value ocean_proximity  index
# 0        4.844187         8.3252            452600.0        NEAR BAY      1
# ...

# %%
df = cln_mincome

# %%
df.shape
# Out:
# (19858, 9)

# %%
df.hist(figsize = (15, 8))
# Out:
# array([[<AxesSubplot: title={'center': 'housing_median_age'}>,
#         <AxesSubplot: title={'center': 'total_rooms'}>,
#         <AxesSubplot: title={'center': 'total_bedrooms'}>],
#        [<AxesSubplot: title={'center': 'population'}>,
#         <AxesSubplot: title={'center': 'households'}>,
#         <AxesSubplot: title={'center': 'median_income'}>],
#        [<AxesSubplot: title={'center': 'median_house_value'}>,
#         <AxesSubplot: title={'center': 'index'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
sns.lmplot(data=df, x ='index', y='median_house_value')
