# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('./Data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
# df = df[['housing_median_age','total_rooms','total_bedrooms','population', 'households', 'median_income','median_house_value', 'ocean_proximity']]


#df_sub

# %%
#df_sub = df.rename(columns={'housing_median_age': 'housing_median_age',
                         #'total_rooms': 'total_rooms_sqft', 
                         #'total_bedrooms': 'total_bedrooms_sqft',
                          #'population': 'population', 
                          #'median_income': 'median_income',
                          #'median_house_value': 'median_house_value',
                          # 'ocean_proximity': 'ocean_proximity'})

#df_sub

# %%
## DATA CLEANING

# %%
df.isnull().count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20640
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(537)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.hist(figsize = (15, 8))
# Out:
# array([[<AxesSubplot: title={'center': 'longitude'}>,
#         <AxesSubplot: title={'center': 'latitude'}>,
#         <AxesSubplot: title={'center': 'housing_median_age'}>],
#        [<AxesSubplot: title={'center': 'total_rooms'}>,
#         <AxesSubplot: title={'center': 'total_bedrooms'}>,
#         <AxesSubplot: title={'center': 'population'}>],
#        [<AxesSubplot: title={'center': 'households'}>,
#         <AxesSubplot: title={'center': 'median_income'}>,
#         <AxesSubplot: title={'center': 'median_house_value'}>]],
#       dtype=object)

# %%
df.shape
# Out:
# (20640, 10)

# %%
#df['total_rooms'] = np.log(df['total_rooms'] + 1)
#df['total_bedrooms'] = np.log(df['total_bedrooms'] + 1)
#df['population'] = np.log(df['population'] + 1)
#df['households'] = np.log(df['households'] + 1)

# %%
#train[(train['price'] < 2100000) & (train['price'] > 300000)]

# %%
df['total_rooms'].describe()
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
df.shape
# Out:
# (20640, 10)

# %%
## df['total_rooms'].plot(kind='box', vert=True)
# Out:
# <AxesSubplot: >

# %%
df['index'] = range(1, len(df)+1)   ##creating an index to plot

# %%
df.shape
# Out:
# (20640, 11)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.shape
# Out:
# (20640, 11)

# %%
df.shape
# Out:
# (20640, 11)

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
sns.lmplot(data=df, x ='index', y='total_rooms')

# %%
df.shape
# Out:
# (20640, 11)

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 126

# %%
mask = df['total_rooms'] < 15000

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 20543

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 126

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 126

# %%
## clean total number of rooms

# %%
df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)].count()
# Out:
# longitude             20416
# latitude              20416
# housing_median_age    20416
# total_rooms           20416
# total_bedrooms        20416
# population            20416
# households            20416
# median_income         20416
# median_house_value    20416
# ocean_proximity       20416
# index                 20416
# dtype: int64

# %%
cln_trooms = df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)]
cln_trooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
cln_trooms.count()
# Out:
# longitude             20416
# latitude              20416
# housing_median_age    20416
# total_rooms           20416
# total_bedrooms        20416
# population            20416
# households            20416
# median_income         20416
# median_house_value    20416
# ocean_proximity       20416
# index                 20416
# dtype: int64

# %%
df.shape
# Out:
# (20640, 11)

# %%
sns.lmplot(data=df, x ='index', y='total_rooms')

# %%
## Total_rooms cleaned and values between 100 and 15,000 remaining.   
## Values outside this range are considered Outliars and have been removed.

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
## Removing Outlias from total_bedrooms

# %%
##df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)].count()

# %%
df['total_bedrooms'].describe()
# Out:
# count    20416.000000
# mean       527.502302
# std        364.239840
# min         16.000000
# 25%        299.000000
# 50%        438.000000
# 75%        641.000000
# max       4183.000000
# Name: total_bedrooms, dtype: float64

# %%
sns.lmplot(data=df, x ='index', y='total_bedrooms')

# %%
df = cln_trooms

# %%
mask = df['total_bedrooms'] < 20

mask2 = df['total_bedrooms'][mask]
mask2.count()
# Out:
# 11

# %%
mask = df['total_bedrooms'] > 2000

mask2 = df['total_bedrooms'][mask]
mask2.count()
# Out:
# 174

# %%
df[(df['total_bedrooms'] > 20) & (df['total_bedrooms']  < 2000)].count()
# Out:
# longitude             20223
# latitude              20223
# housing_median_age    20223
# total_rooms           20223
# total_bedrooms        20223
# population            20223
# households            20223
# median_income         20223
# median_house_value    20223
# ocean_proximity       20223
# index                 20223
# dtype: int64

# %%
cln_bedrooms = df[(df['total_bedrooms'] > 20) & (df['total_bedrooms']  < 2000)]
cln_bedrooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = cln_bedrooms
df.shape
# Out:
# (20223, 11)

# %%
sns.lmplot(data=df, x ='index', y='total_bedrooms')

# %%
## values between 20 and 2000 sqft are valie and  outliars removed (getting ready for dataprep with pycaret no need to standadize for now)

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
## Removing Outlias from population

# %%
sns.lmplot(data=df, x ='index', y='population')

# %%
mask = df['population'] < 50

mask2 = df['population'][mask]
mask2.count()
# Out:
# 16

# %%
mask = df['population'] > 6000

mask2 = df['population'][mask]
mask2.count()
# Out:
# 35

# %%
cln_population = df[(df['population'] > 50) & (df['population']  < 6000)]
cln_population
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = cln_population
df.shape
# Out:
# (20169, 11)

# %%
sns.lmplot(data=df, x ='index', y='population')

# %%
##  out liars removed

# %%
## Removing Outlias from  households , median_income

# %%
sns.lmplot(data=df, x ='index', y='households')

# %%
mask = df['households'] < 30

mask2 = df['households'][mask]
mask2.count()
# Out:
# 41

# %%
mask = df['households'] > 1500

mask2 = df['households'][mask]
mask2.count()
# Out:
# 212

# %%
cln_households = df[(df['households'] > 30) & (df['households']  < 1500)]
cln_households
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = cln_households

# %%
sns.lmplot(data=df, x ='index', y='households')

# %%
## Removing Outlias from  median_income

# %%
sns.lmplot(data=df, x ='index', y='median_income')

# %%
df['median_income'].describe()
# Out:
# count    19909.000000
# mean         3.862205
# std          1.887830
# min          0.499900
# 25%          2.560300
# 50%          3.526800
# 75%          4.735600
# max         15.000100
# Name: median_income, dtype: float64

# %%
mask = df['median_income'] > 10

mask2 = df['median_income'][mask]
mask2.count()
# Out:
# 291

# %%
mask = df['median_income'] < 0

mask2 = df['median_income'][mask]
mask2.count()
# Out:
# 0

# %%
cln_median_income = df[(df['median_income'] > 0) & (df['median_income']  < 10)]
cln_median_income
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = cln_median_income
df.shape
# Out:
# (19617, 11)

# %%
sns.lmplot(data=df, x ='index', y='median_income')

# %%
# Cleaning the median_house_value

# %%
sns.lmplot(data=df, x ='index', y='median_house_value')

# %%
df['median_house_value'].describe()
# Out:
# count     19617.000000
# mean     202379.863078
# std      111001.718310
# min       14999.000000
# 25%      118200.000000
# 50%      177300.000000
# 75%      259300.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
df['median_house_value'].min()
# Out:
# 14999.0

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
mask = df['median_house_value'] < 75000

mask2 = df['median_house_value'][mask]
mask2.count()
# Out:
# 1594

# %%
cln_ouse_value = df[(df['median_house_value'] > 75000) & (df['median_house_value']  < 500001)]
cln_ouse_value
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
sns.lmplot(data=df, x ='index', y='median_house_value')

# %%
##### ALL DATA CLEANED WELL AND NOW WE START MODELING 
### outliars removed

# %%
cln_ouse_value
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = cln_ouse_value

# %%
df.shape
# Out:
# (17320, 11)

# %%
df.to_csv('./Data/cl_housing_data.csv', index=False)

# %%
##### ALL DATA CLEANED WELL AND NOW WE START MODELING

# %%
## REMOVE UNSEEN DATA

# %%
data = df.drop('index', axis=1)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
num_rows = int(len(data) * 0.05)

# %%
data.shape
# Out:
# (15632, 10)

# %%
num_rows = int(len(data) * 0.05)

# %%
unseen_data = data.sample(n=num_rows, random_state=42)

# %%
data = data.drop(unseen_data.index)

# %%
print("data set size:", len(data))
print("unseen set size:", len(unseen_data))
# Out:
# data set size: 16454
# unseen set size: 866

# %%
data.shape
# Out:
# (16454, 10)

# %%
unseen_data.shape
# Out:
# (866, 10)

# %%
df.shape
# Out:
# (17320, 11)

# %%
## nulls removed

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
## Data Prep

# %%
from pycaret.regression import *
reg = setup(data = data, target='median_house_value', normalize=True)
reg
# Out:
# <style type="text/css">
# #T_f08d9_row9_col1, #T_f08d9_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f08d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f08d9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f08d9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f08d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f08d9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f08d9_row0_col1" class="data row0 col1" >5892</td>
#     </tr>
#     <tr>
#       <th id="T_f08d9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f08d9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f08d9_row1_col1" class="data row1 col1" >median_house_value</td>
#     </tr>
#     <tr>
# ...

# %%
compare_models(include = ['catboost','lightgbm'])
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            12:16:50
# Status     . . . . . . . . . . . . . . . . . .    Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  CatBoost Regressor

# %%
pull()
# Out:
#                                     Model         MAE           MSE  \
# catboost               CatBoost Regressor  28990.1407  1.756904e+09
# lightgbm  Light Gradient Boosting Machine  30394.5464  1.908678e+09
#
#                 RMSE      R2   RMSLE    MAPE  TT (Sec)
# catboost  41900.5751  0.7972  0.1987  0.1517     5.744
# lightgbm  43680.0299  0.7796  0.2054  0.1588     2.311

# %%
compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           19:02:16
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Linear Regression
# <style type="text/css">
# #T_2c257 th {
#   text-align: left;
# }
# ...

# %%
lightgbm = create_model('lightgbm')
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         12:21:08
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
lightgbm_tuned_model = tune_model(lightgbm)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
 ## tune_model(lightgbm)

# %%
lightgbm_tuned_model2 = tune_model(lightgbm ,  fold = 15)
# Out:
# Fitting 15 folds for each of 10 candidates, totalling 150 fits

# %%
pull()
# Out:
#              MAE           MSE        RMSE      R2   RMSLE    MAPE
# Fold
# 0     29067.4380  1.867841e+09  43218.5293  0.7778  0.2056  0.1504
# 1     28224.2925  1.654317e+09  40673.3019  0.8111  0.1969  0.1495
# 2     30313.3241  1.840110e+09  42896.5073  0.7783  0.2121  0.1626
# 3     29540.4133  1.821680e+09  42681.1392  0.7847  0.2082  0.1542
# 4     31282.3799  1.958987e+09  44260.4401  0.7783  0.2163  0.1666
# 5     28335.7772  1.640758e+09  40506.2682  0.8067  0.1951  0.1512
# 6     30768.9330  1.946512e+09  44119.2908  0.7708  0.2032  0.1553
# 7     29435.2155  1.739098e+09  41702.4974  0.8022  0.2017  0.1553
# 8     29554.7642  1.725925e+09  41544.2591  0.7933  0.2021  0.1583
# 9     30666.5600  2.003287e+09  44758.0949  0.7736  0.2140  0.1565
# 10    30125.4124  1.949518e+09  44153.3520  0.7849  0.2083  0.1571
# 11    29561.7179  1.800650e+09  42434.0661  0.7910  0.2079  0.1589
# 12    30225.1491  1.830363e+09  42782.7433  0.7897  0.2024  0.1576
# ...

# %%
tune_model(lightgbm ,  fold = 15)
# Out:
# Fitting 15 folds for each of 10 candidates, totalling 150 fits
# LGBMRegressor(random_state=1676)

# %%
print(lightgbm_tuned_model2)
# Out:
# LGBMRegressor(bagging_fraction=0.8, bagging_freq=0, feature_fraction=0.8,
#               learning_rate=0.15, min_child_samples=86, min_split_gain=0.5,
#               n_estimators=220, num_leaves=80, random_state=5892, reg_alpha=5,
#               reg_lambda=0.01)

# %%
final_model = finalize_model(lightgbm_tuned_model2)
final_model
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['longitude', 'latitude',
#                                              'housing_median_age',
#                                              'total_rooms', 'total_bedrooms',
#                                              'population', 'households',
#                                              'median_income'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['ocean_proximity'...
#                                     transformer=OneHotEncoder(cols=['ocean_proximity'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
# ...

# %%
save_model(final_model, './models/housing_lightgbm2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['longitude', 'latitude',
#                                               'housing_median_age',
#                                               'total_rooms', 'total_bedrooms',
#                                               'population', 'households',
#                                               'median_income'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['ocean_proximity'...
#                                      transformer=OneHotEncoder(cols=['ocean_proximity'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
# ...

# %%
#### Load model

# %%
### TESTING MODEL

# %%
model_test = load_model('./models/housing_lightgbm2')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# 5       413.0       193.0         4.0368            269700.0        NEAR BAY

# %%
## data_test = [[ -117.51,	34.00,	36.0,	3791.0,	746.0,	2258.0,	672.0,	3.2067,'INLAND']]

# %%
data_test = [[-122.24,	37.85,	52.0,	1467.0,	190.0,	496.0,	177.0,	7.2574,'NEAR BAY']]

# %%
data_test
pd.DataFrame(data_test)
# Out:
#         0      1     2       3      4      5      6       7         8
# 0 -122.24  37.85  52.0  1467.0  190.0  496.0  177.0  7.2574  NEAR BAY

# %%
cols = model_test.feature_names_in_[:-1]
cols
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity']

# %%
pd.DataFrame(cols)
# Out:
#                     0
# 0           longitude
# 1            latitude
# 2  housing_median_age
# 3         total_rooms
# 4      total_bedrooms
# 5          population
# 6          households
# 7       median_income
# 8     ocean_proximity

# %%
cols = model_test.feature_names_in_[:-1]
test_data = pd.DataFrame(data_test, columns=cols)
prediction = model_test.predict(test_data)[0]
prediction
# Out:
# 385404.7172319881

# %%
act_pred = 352100.0
act_pred
# Out:
# 352100.0

# %%
new_pred = prediction.round(2)
new_pred
# Out:
# 385404.72

# %%
MAE =  new_pred - act_pred 
MAE
# Out:
# 33304.71999999997

# %%
MPAE = MAE/act_pred
MPAE
# Out:
# 0.09458880999715982

# %%
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# ...          ...       ...                 ...          ...             ...
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
unseen_batch = unseen_data.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity']]
unseen_batch
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# ...          ...       ...                 ...          ...             ...
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
unseen_batch.shape
# Out:
# (866, 9)

# %%
unseen_data.shape
# Out:
# (866, 10)

# %%
unseen_predictions = model_test.predict(unseen_batch)
unseen_predictions
# Out:
# array([236404.71573438, 183667.80169638, 213333.16135689, 134785.62582816,
#        178705.5602094 , 123986.31559824, 321195.25250792, 218555.35969644,
#        225922.44132325, 201739.99345347, 167999.21482048, 385648.52892117,
#        165009.21512853, 204393.9649992 , 319095.69727314, 182497.67314933,
#        312177.55573231, 230748.20271563, 108337.25245367, 278325.79855321,
#        124949.78411859, 350513.3752795 , 124400.93327564, 238444.37345738,
#        196966.64975806, 129346.69720042, 333457.72355282, 135103.54696231,
#        329207.9414146 , 205368.4554525 , 174118.27253573, 238839.20692047,
#         66281.11278358, 145336.73841913,  79114.76805759, 404011.50532599,
#        226255.95856542, 108408.65519791, 116842.23543608, 103720.07575994,
#        187118.14917484, 108694.49361047, 391121.44963175, 373704.3616143 ,
#        199471.48634589, 200624.03807377, 188956.73106629, 242012.81227659,
# ...

# %%
unseen_data['y-hat'] = np.round(unseen_predictions,2)
unseen_data['y-hat']
# Out:
# 180      236404.72
# 11201    183667.80
# 4593     213333.16
# 2976     134785.63
# 15530    178705.56
#            ...
# 20438    316431.54
# 9093     111549.86
# 11593    279094.18
# 1567     347850.12
# 10233    169063.80
# Name: y-hat, Length: 866, dtype: float64

# %%
unseen_data['pct_err'] = (abs(unseen_data['median_house_value'] - unseen_data['y-hat'])) / unseen_data['median_house_value']
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# ...          ...       ...                 ...          ...             ...
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# ...          ...       ...                 ...          ...             ...
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
unseen_data = unseen_data.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity','median_house_value']]

# %%
unseen_data['y-hat'] = np.round(unseen_predictions,2)
unseen_data['y-hat']
# Out:
# 180      236404.72
# 11201    183667.80
# 4593     213333.16
# 2976     134785.63
# 15530    178705.56
#            ...
# 20438    316431.54
# 9093     111549.86
# 11593    279094.18
# 1567     347850.12
# 10233    169063.80
# Name: y-hat, Length: 866, dtype: float64

# %%
unseen_data['pct_err'] = (abs(unseen_data['median_house_value'] - unseen_data['y-hat'])) / unseen_data['median_house_value']
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# ...          ...       ...                 ...          ...             ...
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
outliars_unseen = unseen_data[unseen_data['pct_err'] > 0.15].shape
outliars_unseen
# Out:
# (312, 12)

# %%
unseen_data.shape
# Out:
# (866, 12)

# %%
good_unseen = unseen_data[unseen_data['pct_err'] < 0.15].shape
good_unseen
# Out:
# (554, 12)

# %%
MAE = outliars_unseen[0]/ unseen_data.shape[0]  ## MEAN AVEAGE ERROR
MAE
# Out:
# 0.36027713625866054

# %%
MAP = good_unseen[0]/ unseen_data.shape[0]   ## MEAN AVERAGE PASS
MAP
# Out:
# 0.6397228637413395

# %%
## FURTHER BI EDA ANALYSIS BELOW (JUST RESERCHING THE DATA TO GET A CLEARER PICTURE BEFOEE ETL AND VISUALIZATION)
## 60% of the time the model prediction was within 85% range

# %%
##outliars_unseen_w = unseen_data[unseen_data['pct_err'] > 1].shape
## outliars_unseen_w
# Out:
# (2, 12)

# %%
### GET VALUES THAT ARE ABOVE 15%

# %%
outliars_unseen_df = unseen_data[unseen_data['pct_err'] > 0.15]
outliars_unseen_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 180      -122.24     37.80                49.0       2838.0           749.0
# 10867    -117.88     33.70                17.0       5122.0          1544.0
# 7816     -118.11     33.88                35.0       1623.0           304.0
# 110      -122.25     37.82                52.0       1424.0           289.0
# 20531    -121.81     38.58                17.0       1964.0           314.0
# ...          ...       ...                 ...          ...             ...
# 19724    -121.69     38.87                38.0        412.0            93.0
# 1475     -122.03     37.97                20.0       3968.0           931.0
# 2656     -124.25     40.28                32.0       1430.0           419.0
# 20438    -118.79     34.26                17.0       1986.0           249.0
# 9093     -118.27     34.68                19.0        552.0           129.0
#
# ...

# %%
good_unseen_df = unseen_data[unseen_data['pct_err'] < 0.15]
good_unseen_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11201    -117.92     33.83                17.0        382.0            86.0
# 4593     -118.27     34.05                26.0       1164.0           674.0
# 2976     -119.09     35.33                 9.0       7085.0          1148.0
# 15530    -117.10     33.15                 5.0       3159.0           685.0
# 9769     -121.32     36.43                22.0       2927.0           637.0
# ...          ...       ...                 ...          ...             ...
# 14549    -117.24     32.95                18.0       1591.0           268.0
# 14552    -117.13     32.97                10.0       3486.0           469.0
# 11593    -118.04     33.78                25.0       3715.0           575.0
# 1567     -121.97     37.76                 8.0       3743.0           581.0
# 10233    -117.89     33.86                28.0       1395.0           398.0
#
# ...

# %%
## NOT ALL MODELS ARE GOOD OR BAD BUT SOME ARE USEFUL

# %%
### JUST PLAYING AROUND WITH EDA SO I CAN GET BETTER INSIGHNT ON THE DATA BEFORE ETL DATA WRANGLING AND VISUALZATION

# %%
outliars_unseen_df.groupby(['median_house_value','ocean_proximity']).count()
# Out:
#                                     longitude  latitude  housing_median_age  \
# median_house_value ocean_proximity
# 75300.0            INLAND                   1         1                   1
# 75700.0            NEAR BAY                 1         1                   1
# 75800.0            INLAND                   1         1                   1
# 76100.0            NEAR OCEAN               1         1                   1
# 76200.0            INLAND                   1         1                   1
# ...                                       ...       ...                 ...
# 470000.0           NEAR BAY                 1         1                   1
# 488500.0           NEAR OCEAN               1         1                   1
# 490300.0           NEAR OCEAN               1         1                   1
# 500000.0           INLAND                   1         1                   1
#                    NEAR OCEAN               1         1                   1
#
# ...

# %%
outliars_unseen_df.groupby(['longitude','latitude']).count()
# Out:
#                     housing_median_age  total_rooms  total_bedrooms  \
# longitude latitude
# -124.25   40.28                      1            1               1
# -124.13   40.55                      1            1               1
# -123.18   39.23                      1            1               1
# -122.71   38.34                      1            1               1
# -122.62   38.24                      1            1               1
# ...                                ...          ...             ...
# -116.50   33.69                      1            1               1
# -116.48   33.96                      1            1               1
# -116.40   34.12                      1            1               1
# -115.56   32.78                      1            1               1
# -115.37   32.82                      1            1               1
#
#                     population  households  median_income  ocean_proximity  \
# longitude latitude
# ...

# %%
outliars_unseen_df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     125
# INLAND        101
# NEAR OCEAN     53
# NEAR BAY       33
# Name: ocean_proximity, dtype: int64

# %%
unseen_data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     428
# INLAND        245
# NEAR OCEAN    110
# NEAR BAY       82
# ISLAND          1
# Name: ocean_proximity, dtype: int64

# %%
unseen_data['total_bedrooms'].value_counts()
# Out:
# 537.0     8
# 292.0     6
# 393.0     6
# 277.0     5
# 430.0     5
#          ..
# 1200.0    1
# 434.0     1
# 1336.0    1
# 792.0     1
# 74.0      1
# Name: total_bedrooms, Length: 526, dtype: int64

# %%
outliars_unseen_df['total_bedrooms'].count()
# Out:
# 312

# %%
##CREATE A RELATIONSHIP BETWEEEN INCOME, BEACH PROXIMITY AND HOUSE ESTIMATE

# %%
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
# ...
