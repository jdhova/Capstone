# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ('./Data/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# df = df[['housing_median_age','total_rooms','total_bedrooms','population', 'households', 'median_income','median_house_value', 'ocean_proximity']]


#df_sub

# %%
#df_sub = df.rename(columns={'housing_median_age': 'housing_median_age',
                         #'total_rooms': 'total_rooms_sqft', 
                         #'total_bedrooms': 'total_bedrooms_sqft',
                          #'population': 'population', 
                          #'median_income': 'median_income',
                          #'median_house_value': 'median_house_value',
                          # 'ocean_proximity': 'ocean_proximity'})

#df_sub

# %%
df.isnull().count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20640
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['total_bedrooms'].describe()
# Out:
# count    20433.000000
# mean       537.870553
# std        421.385070
# min          1.000000
# 25%        296.000000
# 50%        435.000000
# 75%        647.000000
# max       6445.000000
# Name: total_bedrooms, dtype: float64

# %%
df['total_bedrooms'] = df['total_bedrooms'].fillna(537)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.hist(figsize = (15, 8))
# Out:
# array([[<AxesSubplot: title={'center': 'longitude'}>,
#         <AxesSubplot: title={'center': 'latitude'}>,
#         <AxesSubplot: title={'center': 'housing_median_age'}>],
#        [<AxesSubplot: title={'center': 'total_rooms'}>,
#         <AxesSubplot: title={'center': 'total_bedrooms'}>,
#         <AxesSubplot: title={'center': 'population'}>],
#        [<AxesSubplot: title={'center': 'households'}>,
#         <AxesSubplot: title={'center': 'median_income'}>,
#         <AxesSubplot: title={'center': 'median_house_value'}>]],
#       dtype=object)

# %%
df.shape
# Out:
# (20640, 10)

# %%
#df['total_rooms'] = np.log(df['total_rooms'] + 1)
#df['total_bedrooms'] = np.log(df['total_bedrooms'] + 1)
#df['population'] = np.log(df['population'] + 1)
#df['households'] = np.log(df['households'] + 1)

# %%
#train[(train['price'] < 2100000) & (train['price'] > 300000)]

# %%
df['total_rooms'].describe()
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %%
df.shape
# Out:
# (20640, 11)

# %%
## df['total_rooms'].plot(kind='box', vert=True)
# Out:
# <AxesSubplot: >

# %%
df['index'] = range(1, len(df)+1)   ##creating an index to plot

# %%
df.shape
# Out:
# (20640, 11)

# %%
df.shape
# Out:
# (20640, 11)

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
sns.lmplot(data=df, x ='index', y='total_rooms')

# %%
df.shape
# Out:
# (20640, 11)

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 126

# %%
mask = df['total_rooms'] < 15000

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 20416

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()
# Out:
# 0

# %%
mask = df['total_rooms'] < 100

mask2 = df['total_rooms'][mask]
mask2.count()

# %%
## clean total number of rooms

# %%
df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)].count()
# Out:
# longitude             20416
# latitude              20416
# housing_median_age    20416
# total_rooms           20416
# total_bedrooms        20416
# population            20416
# households            20416
# median_income         20416
# median_house_value    20416
# ocean_proximity       20416
# index                 20416
# dtype: int64

# %%
cln_trooms = df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)]
cln_trooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [20416 rows x 11 columns]

# %%
cln_trooms.count()
# Out:
# longitude             20416
# latitude              20416
# housing_median_age    20416
# total_rooms           20416
# total_bedrooms        20416
# population            20416
# households            20416
# median_income         20416
# median_house_value    20416
# ocean_proximity       20416
# index                 20416
# dtype: int64

# %%
df.shape
# Out:
# (20416, 11)

# %%
sns.lmplot(data=df, x ='index', y='total_rooms')

# %%
## Total_rooms cleaned and values between 100 and 15,000 outliars removed.

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
## Removing Outlias from total_bedrooms

# %%
##df[(df['total_rooms'] > 100) & (df['total_rooms']  < 15000)].count()

# %%
df['total_bedrooms'].describe()
# Out:
# count    20416.000000
# mean       527.502302
# std        364.239840
# min         16.000000
# 25%        299.000000
# 50%        438.000000
# 75%        641.000000
# max       4183.000000
# Name: total_bedrooms, dtype: float64

# %%
sns.lmplot(data=df, x ='index', y='total_bedrooms')

# %%
df = cln_trooms

# %%
mask = df['total_bedrooms'] < 20

mask2 = df['total_bedrooms'][mask]
mask2.count()
# Out:
# 11

# %%
mask = df['total_bedrooms'] > 2000

mask2 = df['total_bedrooms'][mask]
mask2.count()
# Out:
# 174

# %%
df[(df['total_bedrooms'] > 20) & (df['total_bedrooms']  < 2000)].count()
# Out:
# longitude             20223
# latitude              20223
# housing_median_age    20223
# total_rooms           20223
# total_bedrooms        20223
# population            20223
# households            20223
# median_income         20223
# median_house_value    20223
# ocean_proximity       20223
# index                 20223
# dtype: int64

# %%
cln_bedrooms = df[(df['total_bedrooms'] > 20) & (df['total_bedrooms']  < 2000)]
cln_bedrooms
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [20223 rows x 11 columns]

# %%
df = cln_bedrooms
df.shape
# Out:
# (20223, 11)

# %%
sns.lmplot(data=df, x ='index', y='total_bedrooms')

# %%
## Removing Outlias from total_rooms , total_bedrooms, population , households , median_income

# %%
## Removing Outlias from population

# %%
sns.lmplot(data=df, x ='index', y='population')

# %%
mask = df['population'] < 50

mask2 = df['population'][mask]
mask2.count()
# Out:
# 16

# %%
mask = df['population'] > 6000

mask2 = df['population'][mask]
mask2.count()
# Out:
# 35

# %%
cln_population = df[(df['population'] > 50) & (df['population']  < 6000)]
cln_population
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [20169 rows x 11 columns]

# %%
df = cln_population
df.shape
# Out:
# (20169, 11)

# %%
sns.lmplot(data=df, x ='index', y='population')

# %%
## Removing Outlias from  households , median_income

# %%
sns.lmplot(data=df, x ='index', y='households')

# %%
mask = df['households'] < 30

mask2 = df['households'][mask]
mask2.count()
# Out:
# 41

# %%
mask = df['households'] > 1500

mask2 = df['households'][mask]
mask2.count()
# Out:
# 212

# %%
cln_households = df[(df['households'] > 30) & (df['households']  < 1500)]
cln_households
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [19909 rows x 11 columns]

# %%
df = cln_households

# %%
sns.lmplot(data=df, x ='index', y='households')

# %%
## Removing Outlias from  median_income

# %%
sns.lmplot(data=df, x ='index', y='median_income')

# %%
df['median_income'].describe()
# Out:
# count    19909.000000
# mean         3.862205
# std          1.887830
# min          0.499900
# 25%          2.560300
# 50%          3.526800
# 75%          4.735600
# max         15.000100
# Name: median_income, dtype: float64

# %%
mask = df['median_income'] > 10

mask2 = df['median_income'][mask]
mask2.count()
# Out:
# 291

# %%
mask = df['median_income'] < 0

mask2 = df['median_income'][mask]
mask2.count()
# Out:
# 0

# %%
cln_median_income = df[(df['median_income'] > 0) & (df['median_income']  < 10)]
cln_median_income
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [19617 rows x 11 columns]

# %%
df = cln_median_income
df.shape
# Out:
# (19617, 11)

# %%
sns.lmplot(data=df, x ='index', y='median_income')

# %%
# Cleaning the median_house_value

# %%
sns.lmplot(data=df, x ='index', y='median_house_value')

# %%
df['median_house_value'].describe()
# Out:
# count     19617.000000
# mean     202379.863078
# std      111001.718310
# min       14999.000000
# 25%      118200.000000
# 50%      177300.000000
# 75%      259300.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
df['median_house_value'].min()
# Out:
# 14999.0

# %%
df['median_house_value'].max()
# Out:
# 500001.0

# %%
mask = df['median_house_value'] < 75000

mask2 = df['median_house_value'][mask]
mask2.count()
# Out:
# 1594

# %%
cln_ouse_value = df[(df['median_house_value'] > 75000) & (df['median_house_value']  < 500001)]
cln_ouse_value
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [17320 rows x 11 columns]

# %%
sns.lmplot(data=df, x ='index', y='median_house_value')

# %%
##### ALL DATA CLEANED WELL AND NOW WE START MODELING

# %%
cln_ouse_value
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  index
# 0            NEAR BAY      1
# 1            NEAR BAY      2
# 2            NEAR BAY      3
# 3            NEAR BAY      4
# 4            NEAR BAY      5
# ...               ...    ...
# 20635          INLAND  20636
# 20636          INLAND  20637
# 20637          INLAND  20638
# 20638          INLAND  20639
# 20639          INLAND  20640
#
# [17320 rows x 11 columns]

# %%
df = cln_ouse_value

# %%
df.shape
# Out:
# (17320, 11)

# %%
df.to_csv('./Data/cl_housing_data.csv', index=False)

# %%
##### ALL DATA CLEANED WELL AND NOW WE START MODELING

# %%
## REMOVE UNSEEN DATA

# %%
data = df.drop('index', axis=1)
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [17320 rows x 10 columns]

# %%
num_rows = int(len(data) * 0.05)

# %%
data.shape
# Out:
# (15632, 10)

# %%
num_rows = int(len(data) * 0.05)

# %%
unseen_data = data.sample(n=num_rows, random_state=42)

# %%
data = data.drop(unseen_data.index)

# %%
print("data set size:", len(data))
print("unseen set size:", len(unseen_data))
# Out:
# data set size: 14851
# unseen set size: 781

# %%
data.shape
# Out:
# (14851, 10)

# %%
unseen_data.shape
# Out:
# (781, 10)

# %%
df.shape
# Out:
# (17320, 11)

# %%
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
## Data Prep

# %%
from pycaret.regression import *
reg = setup(data = data, target='median_house_value', normalize=True)
reg
# Out:
# <style type="text/css">
# #T_fcfe9_row9_col1, #T_fcfe9_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fcfe9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcfe9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_
row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_2c257_row2_col1" class="data row2 col1" >31876.3869</td>
#       <td id="T_2c257_row2_col2" class="data row2 col2" >2130955425.1433</td>
#       <td id="T_2c257_row2_col3" class="data row2 col3" >46136.9188</td>
#       <td id="T_2c257_row2_col4" class="data row2 col4" >0.7504</td>
#       <td id="T_2c257_row2_col5" class="data row2 col5" >0.2143</td>
#       <td id="T_2c257_row2_col6" class="data row2 col6" >0.1659</td>
#       <td id="T_2c257_row2_col7" class="data row2 col7" >4.3300</td>
#     </tr>
#     <tr>
#       <th id="T_2c257_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_2c257_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_2c257_row3_col1" class="data row3 col1" >33910.9064</td>
#       <td id="T_2c257_row3_col2" class="data row3 col2" >2320699753.5376</td>
#       <td id="T_2c257_row3_col3" class="data row3 col3" >48145.4892</td>
#       <td id="T_2c257_row3_col4" class="data row3 col4" >0.7285</td>
#       <td id="T_2c257_row3_col5" class="data row3 col5" >0.2249</td>
#       <td id="T_2c257_row3_col6" class="data row3 col6" >0.1781</td>
#       <td id="T_2c257_row3_col7" class="data row3 col7" >2.5060</td>
#     </tr>
#     <tr>
#       <th id="T_2c257_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_2c257_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_2c257_row4_col1" class="data row4 col1" >36512.0332</td>
#       <td id="T_2c257_row4_col2" class="data row4 col2" >2557593027.4084</td>
#       <td id="T_2c257_row4_col3" class="data row4 col3" >50559.2893</td>
#       <td id="T_2c257_row4_col4" class="data row4 col4" >0.7005</td>
#       <td id="T_2c257_row4_col5" class="data row4 col5" >0.2406</td>
#       <td id="T_2c257_row4_col6" class="data row4 col6" >0.1942</td>
#       <td id="T_2c257_row4_col7" class="data row4 col7" >1.9090</td>
#     </tr>
#     <tr>
#       <th id="T_2c257_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_2c257_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_2c257_row5_col1" class="data row5 col1" >40122.5656</td>
#       <td id="T_2c257_row5_col2" class="data row5 col2" >3203386214.4000</td>
#       <td id="T_2c257_row5_col3" class="data row5 col3" >56574.3074</td>
#       <td id="T_2c257_row5_col4" class="data row5 c

# %%
lightgbm = create_model('lightgbm')
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         19:10:09
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
lightgbm_tuned_model = tune_model(lightgbm)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
 tune_model(lightgbm)

# %%
lightgbm_tuned_model2 = tune_model(lightgbm ,  fold = 15)
# Out:
# Fitting 15 folds for each of 10 candidates, totalling 150 fits

# %%
tune_model(lightgbm ,  fold = 15)
# Out:
# Fitting 15 folds for each of 10 candidates, totalling 150 fits
# LGBMRegressor(random_state=1676)

# %%
print(lightgbm_tuned_model2)
# Out:
# LGBMRegressor(random_state=1676)

# %%
final_model = finalize_model(lightgbm_tuned_model2)
final_model
# Out:
# Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(include=['longitude', 'latitude',
#                                              'housing_median_age',
#                                              'total_rooms', 'total_bedrooms',
#                                              'population', 'households',
#                                              'median_income'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer',
#                  TransformerWrapper(include=['ocean_proximity'],
#                                     transformer=SimpleImputer(strategy='most_frequent'))),
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['ocean_proximity'],
#                                     transformer=OneHotEncoder(cols=['ocean_proximity'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                 ('actual_estimator', LGBMRegressor(random_state=1676))])

# %%
save_model(final_model, './models/housing_lightgbm2')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\juud0\AppData\Local\Temp\joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['longitude', 'latitude',
#                                               'housing_median_age',
#                                               'total_rooms', 'total_bedrooms',
#                                               'population', 'households',
#                                               'median_income'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['ocean_proximity'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['ocean_proximity'],
#                                      transformer=OneHotEncoder(cols=['ocean_proximity'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('normalize', TransformerWrapper(transformer=StandardScaler())),
#                  ('actual_estimator', LGBMRegressor(random_state=1676))]),
#  './models/housing_lightgbm2.pkl')

# %%
#### Load model

# %%
model_test = load_model('./models/housing_lightgbm2')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 6    -122.25     37.84                52.0       2535.0           489.0
# 7    -122.25     37.84                52.0       3104.0           687.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 6      1094.0       514.0         3.6591            299200.0        NEAR BAY
# 7      1157.0       647.0         3.1200            241400.0        NEAR BAY

# %%
## data_test = [[ -117.51,	34.00,	36.0,	3791.0,	746.0,	2258.0,	672.0,	3.2067,'INLAND']]

# %%
data_test = [[-122.24,	37.85,	52.0,	1467.0,	190.0,	496.0,	177.0,	7.2574,'NEAR BAY']]

# %%
data_test
pd.DataFrame(data_test)
# Out:
#         0      1     2       3      4      5      6       7         8
# 0 -122.24  37.85  52.0  1467.0  190.0  496.0  177.0  7.2574  NEAR BAY

# %%
cols = model_test.feature_names_in_[:-1]
cols
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'ocean_proximity']

# %%
pd.DataFrame(cols)
# Out:
#                     0
# 0           longitude
# 1            latitude
# 2  housing_median_age
# 3         total_rooms
# 4      total_bedrooms
# 5          population
# 6          households
# 7       median_income
# 8     ocean_proximity

# %%
cols = model_test.feature_names_in_[:-1]
test_data = pd.DataFrame(data_test, columns=cols)
prediction = model_test.predict(test_data)[0]
prediction
# Out:
# 373628.3752591352

# %%
act_pred = 352100.0
act_pred
# Out:
# 352100.0

# %%
new_pred = prediction.round(2)
new_pred
# Out:
# 373628.38

# %%
MAE =  new_pred - act_pred 
MAE
# Out:
# 21528.380000000005

# %%
MPAE = MAE/act_pred
MPAE
# Out:
# 0.061142800340812285

# %%
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income  median_house_value  \
# 605        2999.0      1295.0         3.0964            190500.0
# 7791       1651.0       265.0         3.1250            120300.0
# 1588       3280.0      1167.0         8.0030            351300.0
# 15755      1275.0       553.0         3.3500            492900.0
# 8329       1715.0       475.0         1.7244            111200.0
# ...           ...         ...            ...                 ...
# 8514        831.0       291.0         4.0473            212100.0
# 16683      1068.0       552.0         3.5242            156800.0
# 3904       1141.0       379.0         4.2865            221100.0
# 19952      1260.0       455.0         3.0905             78200.0
# 6680        150.0        55.0         2.2321            237500.0
#
#       ocean_proximity
# 605          NEAR BAY
# 7791        <1H OCEAN
# 1588        <1H OCEAN
# 15755        NEAR BAY
# 8329        <1H OCEAN
# ...               ...
# 8514        <1H OCEAN
# 16683       <1H OCEAN
# 3904        <1H OCEAN
# 19952          INLAND
# 6680           INLAND
#
# [781 rows x 10 columns]

# %%
unseen_batch = unseen_data.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity']]
unseen_batch
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income ocean_proximity
# 605        2999.0      1295.0         3.0964        NEAR BAY
# 7791       1651.0       265.0         3.1250       <1H OCEAN
# 1588       3280.0      1167.0         8.0030       <1H OCEAN
# 15755      1275.0       553.0         3.3500        NEAR BAY
# 8329       1715.0       475.0         1.7244       <1H OCEAN
# ...           ...         ...            ...             ...
# 8514        831.0       291.0         4.0473       <1H OCEAN
# 16683      1068.0       552.0         3.5242       <1H OCEAN
# 3904       1141.0       379.0         4.2865       <1H OCEAN
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income  median_house_value  \
# 605        2999.0      1295.0         3.0964            190500.0
# 7791       1651.0       265.0         3.1250            120300.0
# 1588       3280.0      1167.0         8.0030            351300.0
# 15755      1275.0       553.0         3.3500            492900.0
# 8329       1715.0       475.0         1.7244            111200.0
# ...           ...         ...            ...                 ...
# 8514        831.0       291.0         4.0473            212100.0
# 16683      1068.0       552.0         3.5242            156800.0
# 3904       1141.0       379.0         4.2865            221100.0
# 19952      1260.0       455.0         3.0905             78200.0
# 6680        150.0        55.0         2.2321            237500.0
#
#       ocean_proximity      y-hat   pct_err
# 605          NEAR BAY  199295.15  0.046169
# 7791        <1H OCEAN  158940.54  0.321201
# 1588        <1H OCEAN  413668.10  0.177535
# 15755        NEAR BAY  373908.92  0.241410
# 8329        <1H OCEAN  112573.02  0.012347
# ...               ...        ...       ...
# 8514        <1H OCEAN  188507.78  0.111232
# 16683       <1H OCEAN  224257.33  0.430213
# 3904        <1H OCEAN  236018.31  0.067473
# 19952          INLAND   99725.97  0.275268
# 6680           INLAND  199448.45  0.160217
#
# [781 rows x 12 columns]

# %%
unseen_data = unseen_data.loc[:, ['longitude',	'latitude', 'housing_median_age','total_rooms','total_bedrooms','population',	'households',	'median_income','ocean_proximity','median_house_value']]

# %%
unseen_data['y-hat'] = np.round(unseen_predictions,2)
unseen_data['y-hat']
# Out:
# 605      199295.15
# 7791     158940.54
# 1588     413668.10
# 15755    373908.92
# 8329     112573.02
#            ...
# 8514     188507.78
# 16683    224257.33
# 3904     236018.31
# 19952     99725.97
# 6680     199448.45
# Name: y-hat, Length: 781, dtype: float64

# %%
unseen_data['pct_err'] = (abs(unseen_data['median_house_value'] - unseen_data['y-hat'])) / unseen_data['median_house_value']
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income ocean_proximity  \
# 605        2999.0      1295.0         3.0964        NEAR BAY
# 7791       1651.0       265.0         3.1250       <1H OCEAN
# 1588       3280.0      1167.0         8.0030       <1H OCEAN
# 15755      1275.0       553.0         3.3500        NEAR BAY
# 8329       1715.0       475.0         1.7244       <1H OCEAN
# ...           ...         ...            ...             ...
# 8514        831.0       291.0         4.0473       <1H OCEAN
# 16683      1068.0       552.0         3.5242       <1H OCEAN
# 3904       1141.0       379.0         4.2865       <1H OCEAN
# 19952      1260.0       455.0         3.0905          INLAND
# 6680        150.0        55.0         2.2321          INLAND
#
#        median_house_value      y-hat   pct_err
# 605              190500.0  199295.15  0.046169
# 7791             120300.0  158940.54  0.321201
# 1588             351300.0  413668.10  0.177535
# 15755            492900.0  373908.92  0.241410
# 8329             111200.0  112573.02  0.012347
# ...                   ...        ...       ...
# 8514             212100.0  188507.78  0.111232
# 16683            156800.0  224257.33  0.430213
# 3904             221100.0  236018.31  0.067473
# 19952             78200.0   99725.97  0.275268
# 6680             237500.0  199448.45  0.160217
#
# [781 rows x 12 columns]

# %%
outliars_unseen = unseen_data[unseen_data['pct_err'] > 0.15].shape
outliars_unseen
# Out:
# (312, 12)

# %%
unseen_data.shape
# Out:
# (781, 12)

# %%
good_unseen = unseen_data[unseen_data['pct_err'] < 0.15].shape
good_unseen
# Out:
# (469, 12)

# %%
MAE = outliars_unseen[0]/ unseen_data.shape[0]
MAE
# Out:
# 0.3994878361075544

# %%
MAP = good_unseen[0]/ unseen_data.shape[0]   ## MEAN AVERAGE PASS
MAP
# Out:
# 0.6005121638924455

# %%
## FURTHER BI EDA ANALYSIS BELOW (JUST RESERCHING THE DATA TO GET A CLEARER PICTURE BEFOEE ETL AND VISUALIZATION)
## 60% of the time the model prediction was within 85% range

# %%
##outliars_unseen_w = unseen_data[unseen_data['pct_err'] > 1].shape
## outliars_unseen_w
# Out:
# (2, 12)

# %%
### GET VALUES THAT ARE ABOVE 15%

# %%
outliars_unseen_df = unseen_data[unseen_data['pct_err'] > 0.15]
outliars_unseen_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 20030    -119.03     36.08                19.0       2471.0           431.0
# 19593    -120.87     37.60                32.0       4579.0           914.0
# ...          ...       ...                 ...          ...             ...
# 8093     -118.21     33.82                45.0        455.0            92.0
# 2215     -119.84     36.84                12.0       2396.0           290.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income ocean_proximity  \
# 7791       1651.0       265.0         3.1250       <1H OCEAN
# 1588       3280.0      1167.0         8.0030       <1H OCEAN
# 15755      1275.0       553.0         3.3500        NEAR BAY
# 20030      1040.0       426.0         3.2500          INLAND
# 19593      2742.0       856.0         2.6619          INLAND
# ...           ...         ...            ...             ...
# 8093        394.0        89.0         4.9562      NEAR OCEAN
# 2215        863.0       258.0         8.7716          INLAND
# 16683      1068.0       552.0         3.5242       <1H OCEAN
# 19952      1260.0       455.0         3.0905          INLAND
# 6680        150.0        55.0         2.2321          INLAND
#
#        median_house_value      y-hat   pct_err
# 7791             120300.0  158940.54  0.321201
# 1588             351300.0  413668.10  0.177535
# 15755            492900.0  373908.92  0.241410
# 20030             80600.0  108087.18  0.341032
# 19593             86200.0  113071.14  0.311730
# ...                   ...        ...       ...
# 8093             165700.0  217993.87  0.315594
# 2215             229200.0  269015.80  0.173716
# 16683            156800.0  224257.33  0.430213
# 19952             78200.0   99725.97  0.275268
# 6680             237500.0  199448.45  0.160217
#
# [312 rows x 12 columns]

# %%
good_unseen_df = unseen_data[unseen_data['pct_err'] < 0.15]
good_unseen_df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# 5136     -118.26     33.97                46.0       1086.0           249.0
# 4959     -118.29     34.01                50.0       2238.0           673.0
# 3083     -118.44     35.75                23.0       3166.0           700.0
# ...          ...       ...                 ...          ...             ...
# 10043    -120.94     39.22                12.0       1321.0           268.0
# 3901     -118.51     34.20                33.0       2327.0           479.0
# 13918    -116.02     34.18                 8.0        569.0            97.0
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
#
#        population  households  median_income ocean_proximity  \
# 605        2999.0      1295.0         3.0964        NEAR BAY
# 8329       1715.0       475.0         1.7244       <1H OCEAN
# 5136        880.0       250.0         1.5962       <1H OCEAN
# 4959       2247.0       583.0         1.6505       <1H OCEAN
# 3083       1097.0       493.0         2.6288          INLAND
# ...           ...         ...            ...             ...
# 10043       661.0       232.0         4.0062          INLAND
# 3901       1166.0       472.0         4.2344       <1H OCEAN
# 13918       312.0        96.0         4.3021          INLAND
# 8514        831.0       291.0         4.0473       <1H OCEAN
# 3904       1141.0       379.0         4.2865       <1H OCEAN
#
#        median_house_value      y-hat   pct_err
# 605              190500.0  199295.15  0.046169
# 8329             111200.0  112573.02  0.012347
# 5136              95700.0   99721.29  0.042020
# 4959             125000.0  124980.85  0.000153
# 3083              96000.0  110394.22  0.149940
# ...                   ...        ...       ...
# 10043            153800.0  161714.81  0.051462
# 3901             262500.0  254351.49  0.031042
# 13918             94500.0  106737.66  0.129499
# 8514             212100.0  188507.78  0.111232
# 3904             221100.0  236018.31  0.067473
#
# [469 rows x 12 columns]

# %%
## NOT ALL MODELS ARE GOOD OR BAD BUT SOME ARE USEFUL

# %%
outliars_unseen_df.groupby(['median_house_value','ocean_proximity']).count()
# Out:
#                                     longitude  latitude  housing_median_age  \
# median_house_value ocean_proximity
# 76200.0            INLAND                   2         2                   2
# 76900.0            INLAND                   1         1                   1
#                    NEAR OCEAN               1         1                   1
# 77500.0            INLAND                   1         1                   1
# 78200.0            INLAND                   1         1                   1
# ...                                       ...       ...                 ...
# 483300.0           INLAND                   1         1                   1
# 484600.0           <1H OCEAN                1         1                   1
# 492900.0           NEAR BAY                 1         1                   1
# 498400.0           <1H OCEAN                1         1                   1
# 500000.0           NEAR BAY                 1         1                   1
#
#                                     total_rooms  total_bedrooms  population  \
# median_house_value ocean_proximity
# 76200.0            INLAND                     2               2           2
# 76900.0            INLAND                     1               1           1
#                    NEAR OCEAN                 1               1           1
# 77500.0            INLAND                     1               1           1
# 78200.0            INLAND                     1               1           1
# ...                                         ...             ...         ...
# 483300.0           INLAND                     1               1           1
# 484600.0           <1H OCEAN                  1               1           1
# 492900.0           NEAR BAY                   1               1           1
# 498400.0           <1H OCEAN                  1               1           1
# 500000.0           NEAR BAY                   1               1           1
#
#                                     households  median_income  y-hat  pct_err
# median_house_value ocean_proximity
# 76200.0            INLAND                    2              2      2        2
# 76900.0            INLAND                    1              1      1        1
#                    NEAR OCEAN                1              1      1        1
# 77500.0            INLAND                    1              1      1        1
# 78200.0            INLAND                    1              1      1        1
# ...                                        ...            ...    ...      ...
# 483300.0           INLAND                    1              1      1        1
# 484600.0           <1H OCEAN                 1              1      1        1
# 492900.0           NEAR BAY                  1              1      1        1
# 498400.0           <1H OCEAN                 1              1      1        1
# 500000.0           NEAR BAY                  1              1      1        1
#
# [294 rows x 10 columns]

# %%
outliars_unseen_df.groupby(['longitude','latitude']).count()
# Out:
#                     housing_median_age  total_rooms  total_bedrooms  \
# longitude latitude
# -124.19   40.73                      1            1               1
# -124.16   40.79                      1            1               1
# -123.79   39.44                      1            1               1
# -123.21   39.15                      1            1               1
# -123.20   39.15                      1            1               1
# ...                                ...          ...             ...
# -116.82   34.24                      1            1               1
# -116.44   33.77                      1            1               1
# -116.43   34.10                      1            1               1
# -115.60   33.04                      1            1               1
# -114.49   33.97                      1            1               1
#
#                     population  households  median_income  ocean_proximity  \
# longitude latitude
# -124.19   40.73              1           1              1                1
# -124.16   40.79              1           1              1                1
# -123.79   39.44              1           1              1                1
# -123.21   39.15              1           1              1                1
# -123.20   39.15              1           1              1                1
# ...                        ...         ...            ...              ...
# -116.82   34.24              1           1              1                1
# -116.44   33.77              1           1              1                1
# -116.43   34.10              1           1              1                1
# -115.60   33.04              1           1              1                1
# -114.49   33.97              1           1              1                1
#
#                     median_house_value  y-hat  pct_err
# longitude latitude
# -124.19   40.73                      1      1        1
# -124.16   40.79                      1      1        1
# -123.79   39.44                      1      1        1
# -123.21   39.15                      1      1        1
# -123.20   39.15                      1      1        1
# ...                                ...    ...      ...
# -116.82   34.24                      1      1        1
# -116.44   33.77                      1      1        1
# -116.43   34.10                      1      1        1
# -115.60   33.04                      1      1        1
# -114.49   33.97                      1      1        1
#
# [307 rows x 10 columns]

# %%
outliars_unseen_df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     125
# INLAND        101
# NEAR OCEAN     53
# NEAR BAY       33
# Name: ocean_proximity, dtype: int64

# %%
unseen_data['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     369
# INLAND        228
# NEAR OCEAN    114
# NEAR BAY       70
# Name: ocean_proximity, dtype: int64

# %%
unseen_data['total_bedrooms'].value_counts()
# Out:
# 537.0     8
# 292.0     6
# 393.0     6
# 277.0     5
# 430.0     5
#          ..
# 1200.0    1
# 434.0     1
# 1336.0    1
# 792.0     1
# 74.0      1
# Name: total_bedrooms, Length: 526, dtype: int64

# %%
outliars_unseen_df['total_bedrooms'].count()
# Out:
# 312

# %%
##CREATE A RELATIONSHIP BETWEEEN INCOME, BEACH PROXIMITY AND HOUSE ESTIMATE

# %%
unseen_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 605      -122.07     37.69                31.0       5914.0          1309.0
# 7791     -118.07     33.89                35.0       1145.0           274.0
# 1588     -121.98     37.82                18.0       9117.0          1248.0
# 15755    -122.45     37.77                52.0       2645.0           626.0
# 8329     -118.29     33.93                32.0       1815.0           488.0
# ...          ...       ...                 ...          ...             ...
# 8514     -118.32     33.90                36.0       1520.0           300.0
# 16683    -120.57     35.11                18.0       2920.0           556.0
# 3904     -118.51     34.19                38.0       2182.0           409.0
# 19952    -119.34     36.22                38.0       2708.0           460.0
# 6680     -118.09     34.15                46.0        271.0            74.0
#
#        population  households  median_income ocean_proximity  \
# 605        2999.0      1295.0         3.0964        NEAR BAY
# 7791       1651.0       265.0         3.1250       <1H OCEAN
# 1588       3280.0      1167.0         8.0030       <1H OCEAN
# 15755      1275.0       553.0         3.3500        NEAR BAY
# 8329       1715.0       475.0         1.7244       <1H OCEAN
# ...           ...         ...            ...             ...
# 8514        831.0       291.0         4.0473       <1H OCEAN
# 16683      1068.0       552.0         3.5242       <1H OCEAN
# 3904       1141.0       379.0         4.2865       <1H OCEAN
# 19952      1260.0       455.0         3.0905          INLAND
# 6680        150.0        55.0         2.2321          INLAND
#
#        median_house_value      y-hat   pct_err
# 605              190500.0  199295.15  0.046169
# 7791             120300.0  158940.54  0.321201
# 1588             351300.0  413668.10  0.177535
# 15755            492900.0  373908.92  0.241410
# 8329             111200.0  112573.02  0.012347
# ...                   ...        ...       ...
# 8514             212100.0  188507.78  0.111232
# 16683            156800.0  224257.33  0.430213
# 3904             221100.0  236018.31  0.067473
# 19952             78200.0   99725.97  0.275268
# 6680             237500.0  199448.45  0.160217
#
# [781 rows x 12 columns]
